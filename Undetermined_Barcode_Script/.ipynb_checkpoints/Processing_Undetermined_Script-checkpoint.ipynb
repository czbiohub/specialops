# %% [markdown]
# # Undetermined Script Goals
# 1. Read in Undetermined files
# 2. Pull out barcodes and put in dataframe
# 3. Create a tally of all barcodes
# 4. Compare to original barcode plate used in experiment to identify 'hopping'
# 5. Compare to all barcode plates to identify 'mislabelling'

# %% [markdown]
# # Script Outline
# 1. Create a function which reads in an Undetermined file
# 2. Create a function which pulls out barcodes and returns a data frame
# 3. Create a function which tallies all barcodes from a data frame
# 4. Create a function which identifies hopping
# 5. Create a function which identifies mislabelling
# 6. Run all functions and print out hopping and mislabelling results

# %%
import pandas as pd
import timeit
import time

# %% [markdown]
# ## Read an Undetermined File and return a barcode data frame

# %%
index_length = 8

# %%
line=open("Undetermined_S0_R1_001_8bp.fastq", 'r').readline()

# %%
line.find('+')
# Out:
# 60

# %%
line_split=line.split(":")[-1].strip('\n').split('+')
line_split
# Out:
# ['CCCCCCCC', 'CCCCCCCC']

# %%
line_split=line_split[len(line_split)-1]
# Out:
# 'CCCCCCCC+CCCCCCCC'

# %%
undet_length = sum(1 for i in open("Undetermined_S0_R1_001.fastq", 'r'))/4
undet_length
# Out:
# 678466.0

# %%
undetermined_df = pd.DataFrame(index=range(0, int(sum(1 for i in open("Undetermined_S0_R1_001_Test_8bp.fastq", 'r'))/4)),columns=["i7_barcode","i5_barcode"],dtype = 'str')
start = time.clock()
for i, line in enumerate(open("Undetermined_S0_R1_001_Test_8bp.fastq", 'r')):
    if i%4==0:
        undetermined_df['i7_barcode'][i/4] = line[line.find("+")-8:line.find("+")]
        undetermined_df['i5_barcode'][i/4] = line[line.find("+")+1:line.find("+")+9]
print(undet_length)
print(i)
end = time.clock()
print(end-start)
undetermined_df.head(5)
# Out:
# 678466.0
# 3999
# 0.2331700000000012
#   i7_barcode i5_barcode
# 0   CCCCCCCC   CCCCCCCC
# 1   CCCCCTCC   CCCCCCCC
# 2   CTCCCTCC   CCCCCCCC
# 3   TCTACTCT   CCTCCTCT
# 4   TGTATAGT   TTTATATT

# %%
undetermined_df.head(5)
len(undetermined_df2)
# Out:
# 1000

# %%
start = time.clock()
undetermined_list = []
for i, line in enumerate(open("Undetermined_S0_R1_001_Test_8bp.fastq", 'r')):
    if i%4==0:
        undetermined_dict = {'i7_barcode':line[line.find("+")-8:line.find("+")],
                             'i5_barcode':line[line.find("+")+1:line.find("+")+9]}
        undetermined_list.append(undetermined_dict)
undetermined_df2 = pd.DataFrame(undetermined_list, index = None)
end = time.clock()
print(end-start)
undetermined_df2.head(5)
print((undetermined_df.values == undetermined_df2.values).all())
# Out:
# 0.010001999999985856
# False

# %%
start = time.clock()

this_is_a_tuple = (1,2)
this_is_a_list = [1,2]
this_is_a_list[1]
this_is_a_dict = {"a":2}
this_is_a_dict["a"]
tuples = [
    (line[line.find("+")-8:line.find("+")], line[line.find("+")+1:line.find("+")+9])
    for i, line in enumerate(open("Undetermined_S0_R1_001_Test_8bp.fastq", 'r'))
    if i%4==0
]
undetermined_df3 = pd.DataFrame(tuples, columns=["i7_barcode", "i5_barcode"], index = None)
end = time.clock()
print(end-start)
undetermined_df3.head(5)
print((undetermined_df.values == undetermined_df3.values).all())
# Out:
# 0.008353999999997086
# True

# %%
tally = pd.DataFrame(undetermined_df.groupby(['i7_barcode','i5_barcode']).size()).sort_values(by = 0, ascending = False)

# %%
tally[0:10]
# Out:
#                           0
# i7_barcode i5_barcode
# CTCGTTCT   TCTTTCCC    6793
# ACGAGTCG   GGTTAGTG    4816
# GAGTACTG   TCTCTTGC    3571
# GTTCCTTC   TGCTAGTC    3339
# GTTCTCAC   CTCGAATG    3188
# TGCTCTAG   TTACACGC    2903
# CCCCCCCC   CCCCCCCC    2846
# GTTCATGC   GGTGTACA    2791
# ACCGCTAT   CGCTATAC    2747
# TGCTACAC   TGTGGAGA    2379

# %%
master_index_list = pd.read_csv("../TruSeq_8-12bp_Indices_Sample_Sheet/2018-11-02-TRUSEQ-8-12BP-INDEX-PRIMERS-PLATES-001-to-012-MasterIndexList-plus8bp_020619.csv")

# %%
master_index_list
# Out:
#       Dual_Plate_ID Barcode_Well                     i7_plate_ID  \
# 0               NaN          NaN                             NaN
# 1          Dual-001           A1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 2          Dual-001           B1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 3          Dual-001           C1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 4          Dual-001           D1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 5          Dual-001           E1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 6          Dual-001           F1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 7          Dual-001           G1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 8          Dual-001           H1  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 9          Dual-001           A2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 10         Dual-001           B2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 11         Dual-001           C2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 12         Dual-001           D2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 13         Dual-001           E2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 14         Dual-001           F2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 15         Dual-001           G2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 16         Dual-001           H2  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 17         Dual-001           A3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 18         Dual-001           B3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 19         Dual-001           C3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 20         Dual-001           D3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 21         Dual-001           E3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 22         Dual-001           F3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 23         Dual-001           G3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 24         Dual-001           H3  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 25         Dual-001           A4  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 26         Dual-001           B4  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 27         Dual-001           C4  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 28         Dual-001           D4  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# 29         Dual-001           E4  CZB-TRUSEQ-8-12BP-i7-PLATE-001
# ...             ...          ...                             ...
# 13795      Dual-144           C9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13796      Dual-144           D9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13797      Dual-144           E9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13798      Dual-144           F9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13799      Dual-144           G9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13800      Dual-144           H9  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13801      Dual-144          A10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13802      Dual-144          B10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13803      Dual-144          C10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13804      Dual-144          D10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13805      Dual-144          E10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13806      Dual-144          F10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13807      Dual-144          G10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13808      Dual-144          H10  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13809      Dual-144          A11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13810      Dual-144          B11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13811      Dual-144          C11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13812      Dual-144          D11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13813      Dual-144          E11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13814      Dual-144          F11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13815      Dual-144          G11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13816      Dual-144          H11  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13817      Dual-144          A12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13818      Dual-144          B12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13819      Dual-144          C12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13820      Dual-144          D12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13821      Dual-144          E12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13822      Dual-144          F12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13823      Dual-144          G12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
# 13824      Dual-144          H12  CZB-TRUSEQ-8-12BP-i7-PLATE-012
#
#         i7_index_RC                     i5_plate_ID           i5_index_RC  \
# 0               NaN                             NaN  For iSeq and NextSeq
# 1      AGTGCATTCGAG  CZB-TRUSEQ-8-12BP-i5-PLATE-001          AGTGGACTAGCA
# 2      TCACATTCGTCC  CZB-TRUSEQ-8-12BP-i5-PLATE-001          GTTCACCAATCC
# 3      ACGAATCGACCA  CZB-TRUSEQ-8-12BP-i5-PLATE-001          CAAGAGGCACTT
# 4      CTCATGCATCTC  CZB-TRUSEQ-8-12BP-i5-PLATE-001          ACGATCTGCATG
# 5      ACGATACGGCAA  CZB-TRUSEQ-8-12BP-i5-PLATE-001          GTTCTCCGACAT
# 6      GTTCAGATGCTG  CZB-TRUSEQ-8-12BP-i5-PLATE-001          GTTCAGGAGTCT
# 7      GAGTTCTTCGGT  CZB-TRUSEQ-8-12BP-i5-PLATE-001          ACGAGCAAGAGA
# 8      CAAGGCACTGTT  CZB-TRUSEQ-8-12BP-i5-PLATE-001          GTT
# 13806           CATCCTACACTC  ACGATGCC              GAGTGTAG
# 13807           GAAGGTTGGTGA  ACGATACC              TCACCAAC
# 13808           ACGAACGAAGCA  TCACAGTG              TGCTTCGT
# 13809           ATGGAGCTGTGA  TCACTCGA              TCACAGCT
# 13810           TAGACCGTCTTG  TGCTCACT              CAAGACGG
# 13811           TTCCGACACACT  CAAGGCGA              AGTGTGTC
# 13812           ACTCAGACGTGA  CAAGGATT              TCACGTCT
# 13813           TGCTTCTGAGCA  GAGTCTAA              TGCTCAGA
# 13814           AACCTAGCCTTG  GTTCCAGT              CAAGGCTA
# 13815           GATAGGTGTCGT  AGTGCTAT              ACGACACC
# 13816           TCTGGTCATGAG  CTCAGCGA              CTCATGAC
# 13817           GGCCTATAAGCA  GTTCGAGA              TGCTTATA
# 13818           GTGGTATGTCGT  CAAGACTG              ACGACATA
# 13819           GTAAGGCACACT  CTCAAGTC              AGTGTGCC
# 13820           AGTCGTACTGAG  GAGTTAGC              CTCAGTAC
# 13821           ATCCTGTCTCGT  TCACATGA              ACGAGACA
# 13822           AGTCTCGATGAG  GTTCGCCA              CTCATCGA
# 13823           TTGCTGCTCACT  TCACTCTC              AGTGAGCA
# 13824           CTAAGACGGAAC  ACGACTGC              GTTCCGTC
#
#                     i5_8bp_F
# 0      For Miseq and Novaseq
# 1                   TGCTAGTC
# 2                   GGATTGGT
# 3                   AAGTGCCT
# 4                   CATGCAGA
# 5                   ATGTCGGA
# 6                   AGACTCCT
# 7                   TCTCTTGC
# 8                   TAAGGCAC
# 9                   CTCGAATG
# 10                  GGACGAAT
# 11                  TGGTCGAT
# 12                  GAGATGCA
# 13                  TTGCCGTA
# 14                  CAGCATCT
# 15                  ACCGAAGA
# 16                  AACAGTGC
# 17                  AGAGACCA
# 18                  AGCAGAGT
# 19                  ACAGCTAC
# 20                  ATGACACG
# 21                  CCTCCTTA
# 22                  AGGAACCT
# 23                  TTACACGC
# 24                  CGAGAAGA
# 25                  GGTGTACA
# 26                  GAATCGAG
# 27                  CCATACTG
# 28                  AATGGTCG
# 29                  TTAGACCG
# ...                      ...
# 13795               TCACTCAC
# 13796               GGAACAAC
# 13797               GCTTGAGT
# 13798               TGCTGTCA
# 13799               GGATCACA
# 13800               GTGAGTAG
# 13801               TTCCTCGA
# 13802               CTTAAGGC
# 13803               AGTGAGGA
# 13804               ACGTAACG
# 13805               GCTATCAG
# 13806               CATCCTAC
# 13807               GAAGGTTG
# 13808               ACGAACGA
# 13809               ATGGAGCT
# 13810               TAGACCGT
# 13811               TTCCGACA
# 13812               ACTCAGAC
# 13813               TGCTTCTG
# 13814               AACCTAGC
# 13815               GATAGGTG
# 13816               TCTGGTCA
# 13817               GGCCTATA
# 13818               GTGGTATG
# 13819               GTAAGGCA
# 13820               AGTCGTAC
# 13821               ATCCTGTC
# 13822               AGTCTCGA
# 13823               TTGCTGCT
# 13824               CTAAGACG
#
# [13825 rows x 10 columns]

# %%
dual_index_plates = ["Dual-096","Dual-097","Dual-098","Dual-099"]

# %%
subset_master_index_list = master_index_list.loc[master_index_list['Dual_Plate_ID'].isin(dual_index_plates)]

# %%
hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin (subset_master_index_list['i7_index_RC']) & top_undetermined['i5_barcode'].isin (subset_master_index_list['i5_index_RC'])]

# %%
hopped_list = [];
for i in hopped_indices['i7_barcode']:
    hopped_dict = {}
    hopped_dict = {'i7_barcode':i,
                   'i5_barcode': hopped_indices[hopped_indices['i7_barcode']==i]['i5_barcode'].values[0],
                   'reads': hopped_indices[hopped_indices['i7_barcode']==i]['reads'].values[0],
                   'i5_correct':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['i5_index_RC'].values[0],
                   'dual_plate_id':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Dual_Plate_ID'].values[0],
                   'dual_plate_well':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Barcode_Well'].values[0]}
    hopped_list.append(hopped_dict)
    
pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i5_correct','reads','dual_plate_id','dual_plate_well','reads'])
# Out:
#      i7_barcode    i5_barcode    i5_correct  reads dual_plate_id  \
# 0  GAGTCACGATGT  AGTGCTTCGAGT  CAAGCAGTGGTA   1674      Dual-096
# 1  AGTGCATTCGAG  CAAGCAGTGGTA  AGTGCTTCGAGT   1619      Dual-097
#
#   dual_plate_well  reads
# 0              B1   1674
# 1              A1   1619

# %%
hopped_indices
# Out:
#      i7_barcode    i5_barcode  reads
# 2  GAGTCACGATGT  AGTGCTTCGAGT   1674
# 3  AGTGCATTCGAG  CAAGCAGTGGTA   1619

# %%
subset_master_index_list[subset_master_index_list['i7_index_RC']=='GAGTCACGATGT']['i5_index_RC'].map(str)
# Out:
# 9122    CAAGCAGTGGTA
# Name: i5_index_RC, dtype: object

# %%
subset_master_index_list [subset_master_index_list['i5_index_RC'].isin(hopped_indices['i5_barcode'])]
# Out:
#      Dual_Plate_ID Barcode_Well                     i7_plate_ID   i7_index_RC  \
# 9122      Dual-096           B1  CZB-TRUSEQ-8-12BP-i7-PLATE-012  GAGTCACGATGT
# 9217      Dual-097           A1  CZB-TRUSEQ-8-12BP-i7-PLATE-001  AGTGCATTCGAG
#
#                          i5_plate_ID   i5_index_RC    i5_index_F i7_8bp_RC  \
# 9122  CZB-TRUSEQ-8-12BP-i5-PLATE-007  CAAGCAGTGGTA  TACCACTGCTTG  GAGTCACG
# 9217  CZB-TRUSEQ-8-12BP-i5-PLATE-009  AGTGCTTCGAGT  ACTCGAAGCACT  AGTGCATT
#
#      i5_8bp_RC  i5_8bp_F
# 9122  CAAGCAGT  TACCACTG
# 9217  AGTGCTTC  ACTCGAAG

# %%
top_undetermined
# Out:
#      i7_barcode    i5_barcode  reads
# 0  GGGGGGGGGGGG  AGATCTCGGTGG  54985
# 1  GGGGGGGGGGGG  AGATCTCGGGGG   2544
# 2  GAGTCACGATGT  AGTGCTTCGAGT   1674
# 3  AGTGCATTCGAG  CAAGCAGTGGTA   1619
# 4  GGGGGGGGGGGG  AGATCTCGGAGG   1464
# 5  ACGAGTCTAGAG  GAGTAGGAACGG   1315
# 6  CAAGCGACTCTA  GGGGGGGGGGGG    739
# 7  ACGACTATCGCT  GGGGGGGGGGGG    652
# 8  ACGAAGAGGAGT  GGGGGGGGGGGG    648
# 9  ACGAAGCAGGTT  GGGGGGGGGGGG    609

# %%
master_index_list.loc[master_index_list['i7_index_RC'].isin(top_undetermined['i7_barcode']) & master_index_list['i5_index_RC'].isin(top_undetermined['i5_barcode'])]
# Out:
#      Dual_Plate_ID Barcode_Well                     i7_plate_ID   i7_index_RC  \
# 9122      Dual-096           B1  CZB-TRUSEQ-8-12BP-i7-PLATE-012  GAGTCACGATGT
# 9217      Dual-097           A1  CZB-TRUSEQ-8-12BP-i7-PLATE-001  AGTGCATTCGAG
#
#                          i5_plate_ID   i5_index_RC    i5_index_F i7_8bp_RC  \
# 9122  CZB-TRUSEQ-8-12BP-i5-PLATE-007  CAAGCAGTGGTA  TACCACTGCTTG  GAGTCACG
# 9217  CZB-TRUSEQ-8-12BP-i5-PLATE-009  AGTGCTTCGAGT  ACTCGAAGCACT  AGTGCATT
#
#      i5_8bp_RC  i5_8bp_F
# 9122  CAAGCAGT  TACCACTG
# 9217  AGTGCTTC  ACTCGAAG

# %%
top_undetermined.at[2,'i5_barcode'] = 'CAAGCAGTGGTA'
outside_sample_sheet = [];
for i in top_undetermined.index:
    outside_matches = master_index_list.loc[(master_index_list['i7_index_RC']==top_undetermined.loc[i]['i7_barcode'])
          & (master_index_list['i5_index_RC']==top_undetermined.loc[i]['i5_barcode'])]
    if outside_matches.empty:
        outside_dict = {}
        outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                        'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                        'reads' : top_undetermined.loc[i]['reads'],
                        'Dual_Plate_ID' : 'NA',
                        'well' : 'NA',
                        'demux_conclusion': "not a TruSeq dual-unique index pair"}
        outside_sample_sheet.append(outside_dict)
    else:
        outside_dict = {}
        outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                        'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                        'reads' : top_undetermined.loc[i]['reads'],
                        'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                        'well' : outside_matches['Barcode_Well'].values[0],
                        'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"}
        outside_sample_sheet.append(outside_dict)
        print("this sample wrong")
pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])
# Out:
# this sample wrong
#      i7_barcode    i5_barcode  reads  \
# 0  GGGGGGGGGGGG  AGATCTCGGTGG  54985
# 1  GGGGGGGGGGGG  AGATCTCGGGGG   2544
# 2  GAGTCACGATGT  CAAGCAGTGGTA   1674
# 3  AGTGCATTCGAG  CAAGCAGTGGTA   1619
# 4  GGGGGGGGGGGG  AGATCTCGGAGG   1464
# 5  ACGAGTCTAGAG  GAGTAGGAACGG   1315
# 6  CAAGCGACTCTA  GGGGGGGGGGGG    739
# 7  ACGACTATCGCT  GGGGGGGGGGGG    652
# 8  ACGAAGAGGAGT  GGGGGGGGGGGG    648
# 9  ACGAAGCAGGTT  GGGGGGGGGGGG    609
#
#                                     demux_conclusion Dual_Plate_ID well
# 0                not a TruSeq dual-unique index pair            NA   NA
# 1                not a TruSeq dual-unique index pair            NA   NA
# 2  is a TruSeq dual-unique pair, may be outside s...      Dual-096   B1
# 3                not a TruSeq dual-unique index pair            NA   NA
# 4                not a TruSeq dual-unique index pair            NA   NA
# 5                not a TruSeq dual-unique index pair            NA   NA
# 6                not a TruSeq dual-unique index pair            NA   NA
# 7                not a TruSeq dual-unique index pair            NA   NA
# 8                not a TruSeq dual-unique index pair            NA   NA
# 9                not a TruSeq dual-unique index pair            NA   NA

# %%
top_undetermined.loc[(top_undetermined['i7_barcode']!='GGGGGGGGGGGG') & (top_undetermined['i5_barcode']!='GGGGGGGGGGGG') &(top_undetermined['i7_barcode'] !='GGGGGGGG') & (top_undetermined['i5_barcode'] !='GGGGGGGG')]
# Out:
#      i7_barcode    i5_barcode  reads
# 2  GAGTCACGATGT  AGTGCTTCGAGT   1674
# 3  AGTGCATTCGAG  CAAGCAGTGGTA   1619
# 5  ACGAGTCTAGAG  GAGTAGGAACGG   1315

# %%
#IDENTIFY ANY BARCODES WHICH ARE TRUSEQ DUAL UNIQUE FROM top_undetermined_barcodes() DATAFRAME AND RETURN DATAFRAME WITH CONCLUSION
def _TruSeq_dual_unique_check(top_undetermined,sequencer,index_length):  
    if ((len(top_undetermined.loc[0]['i7_barcode']) and len(top_undetermined.loc[0]['i7_barcode'])) != index_length):
        print("Index length does not match Undetermined barcode length.")
        return
    
    outside_sample_sheet = [];
    if ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 12):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_index_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_index_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : 'NA',
                                'well' : 'NA',
                                'demux_conclusion': "not a TruSeq dual-unique index pair"}
                outside_sample_sheet.append(outside_dict)
            else:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                                'well' : outside_matches['Barcode_Well'].values[0],
                                'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"}
                outside_sample_sheet.append(outside_dict)
        return pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 12):        
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_index_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_index_F']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : 'NA',
                                'well' : 'NA',
                                'demux_conclusion': "not a TruSeq dual-unique index pair"}
                outside_sample_sheet.append(outside_dict)
            else:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                                'well' : outside_matches['Barcode_Well'].values[0],
                                'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"}
                outside_sample_sheet.append(outside_dict)
        return pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])
    elif ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 8):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_8bp_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_8bp_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : 'NA',
                                'well' : 'NA',
                                'demux_conclusion': "not a TruSeq dual-unique index pair"}
                outside_sample_sheet.append(outside_dict)
            else:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                                'well' : outside_matches['Barcode_Well'].values[0],
                                'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"}
                outside_sample_sheet.append(outside_dict)
        return pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 8):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_8bp_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_8bp_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : 'NA',
                                'well' : 'NA',
                                'demux_conclusion': "not a TruSeq dual-unique index pair"}
                outside_sample_sheet.append(outside_dict)
            else:
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads'],
                                'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                                'well' : outside_matches['Barcode_Well'].values[0],
                                'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"}
                outside_sample_sheet.append(outside_dict)
        return pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])
    else:
        print("ERROR: wrong sequencer")

# %%
#IDENTIFY ANY BARCODES WHICH ARE TRUSEQ DUAL UNIQUE FROM top_undetermined_barcodes() DATAFRAME AND RETURN FILTERED DATAFRAME
def _TruSeq_dual_unique_filter(top_undetermined,sequencer,index_length):  
    if ((len(top_undetermined.loc[0]['i7_barcode']) and len(top_undetermined.loc[0]['i7_barcode'])) != index_length):
        print("Index length does not match Undetermined barcode length.")
        return
    
    outside_sample_sheet = [];
    if ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 12):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_index_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_index_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads']}
                outside_sample_sheet.append(outside_dict)
        final_data = pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads'])
        print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(final_data)),' barcodes did not match a TruSeq Dual-Unique Index.']))
        return final_data
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 12):        
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_index_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_index_F']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads']}
                outside_sample_sheet.append(outside_dict)
        final_data = pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads'])
        print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(final_data)),' barcodes did not match a TruSeq Dual-Unique Index.']))
        return final_data    
    elif ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 8):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_8bp_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_8bp_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads']}
                outside_sample_sheet.append(outside_dict)
        final_data = pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads'])
        print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(final_data)),' barcodes did not match a TruSeq Dual-Unique Index.']))
        return final_data
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 8):
        for i in top_undetermined.index:
            outside_matches = master_index_list.loc[(master_index_list['i7_8bp_RC']==top_undetermined.loc[i]['i7_barcode'])
                  & (master_index_list['i5_8bp_RC']==top_undetermined.loc[i]['i5_barcode'])]
            if outside_matches.empty:
                outside_dict = {}
                outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                                'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                                'reads' : top_undetermined.loc[i]['reads']}
                outside_sample_sheet.append(outside_dict)
        final_data = pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads'])
        print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(final_data)),' barcodes did not match a TruSeq Dual-Unique Index.']))
        return final_data
    else:
        print("ERROR: wrong sequencer")

# %%
#IDENTIFY ANY TOP UNDETERMINED BARCODES FROM top_undetermined_barcodes() DATAFRAME WHICH MAY HAVE HOPPED ON THIS RUN AND RETURN DATAFRAME
def _hopped_indices(top_undetermined, dual_index_plates, sequencer, index_length):
    if ((len(top_undetermined.loc[0]['i7_barcode']) and len(top_undetermined.loc[0]['i7_barcode'])) != index_length):
        print("Index length does not match Undetermined barcode length.")
        return
        
    #read in master list of barcodes
    master_index_list = pd.read_csv("../TruSeq_8-12bp_Indices_Sample_Sheet/2018-11-02-TRUSEQ-8-12BP-INDEX-PRIMERS-PLATES-001-to-012-MasterIndexList-plus8bp_020619.csv")
    #subset to plates used in this run
    subset_master_index_list = master_index_list.loc[master_index_list['Dual_Plate_ID'].isin(dual_index_plates)]
    hopped_list = [];
    if ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 12):
        #select only those which had i7 & i5 in these plates
        hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin(subset_master_index_list['i7_index_RC']) & top_undetermined['i5_barcode'].isin (subset_master_index_list['i5_index_RC'])]
        #identify the correct i5 based on a fixed i7 and print the correct plate and the location
        for i in hopped_indices['i7_barcode']:
            hopped_dict = {}
            hopped_dict = {'i7_barcode':i,
                           'i5_barcode': hopped_indices[hopped_indices['i7_barcode']==i]['i5_barcode'].values[0],
                           'reads': hopped_indices[hopped_indices['i7_barcode']==i]['reads'].values[0],
                           'i5_correct':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['i5_index_RC'].values[0],
                           'dual_plate_id':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Dual_Plate_ID'].values[0],
                           'dual_plate_well':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Barcode_Well'].values[0]}
            hopped_list.append(hopped_dict)
        final_data = pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i5_correct','reads','dual_plate_id','dual_plate_well','reads'])
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 12):
        #select only those which had i7 & i5 in these plates
        hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin(subset_master_index_list['i7_index_RC']) & top_undetermined['i5_barcode'].isin (subset_master_index_list['i5_index_F'])]
        #identify the correct i5 based on a fixed i7 and print the correct plate and the location
        for i in hopped_indices['i7_barcode']:
            hopped_dict = {}
            hopped_dict = {'i7_barcode':i,
                           'i5_barcode': hopped_indices[hopped_indices['i7_barcode']==i]['i5_barcode'].values[0],
                           'reads': hopped_indices[hopped_indices['i7_barcode']==i]['reads'].values[0],
                           'i5_correct':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['i5_index_RC'].values[0],
                           'dual_plate_id':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Dual_Plate_ID'].values[0],
                           'dual_plate_well':subset_master_index_list[subset_master_index_list['i7_index_RC']==i]['Barcode_Well'].values[0]}
            hopped_list.append(hopped_dict)
        final_data = pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i5_correct','reads','dual_plate_id','dual_plate_well','reads'])
    elif ((sequencer in ['iSeq','NextSeq','iseq','nextseq']) and index_length == 8):
        #select only those which had i7 & i5 in these plates
        hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin(subset_master_index_list['i7_8bp_RC']) & top_undetermined['i5_barcode'].isin (subset_master_index_list['i5_8bp_RC'])]
        #identify the correct i5 based on a fixed i7 and print the correct plate and the location
        for i in hopped_indices['i7_barcode']:
            hopped_dict = {}
            hopped_dict = {'i7_barcode':i,
                           'i5_barcode': hopped_indices[hopped_indices['i7_barcode']==i]['i5_barcode'].values[0],
                           'reads': hopped_indices[hopped_indices['i7_barcode']==i]['reads'].values[0],
                           'i5_correct':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['i5_8bp_RC'].values[0],
                           'dual_plate_id':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['Dual_Plate_ID'].values[0],
                           'dual_plate_well':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['Barcode_Well'].values[0]}
            hopped_list.append(hopped_dict)
        final_data = pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i5_correct','reads','dual_plate_id','dual_plate_well','reads'])
    elif ((sequencer in ['MiSeq','NovaSeq','miseq','novaseq']) and index_length == 8):
        #select only those which had i7 & i5 in these plates
        hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin(subset_master_index_list['i7_8bp_RC']) & top_undetermined['i5_barcode'].isin (subset_master_index_list['i5_8bp_F'])]
        #identify the correct i5 based on a fixed i7 and print the correct plate and the location
        for i in hopped_indices['i7_barcode']:
            hopped_dict = {}
            hopped_dict = {'i7_barcode':i,
                           'i5_barcode': hopped_indices[hopped_indices['i7_barcode']==i]['i5_barcode'].values[0],
                           'reads': hopped_indices[hopped_indices['i7_barcode']==i]['reads'].values[0],
                           'i5_correct':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['i5_8bp_F'].values[0],
                           'dual_plate_id':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['Dual_Plate_ID'].values[0],
                           'dual_plate_well':subset_master_index_list[subset_master_index_list['i7_8bp_RC']==i]['Barcode_Well'].values[0]}
            hopped_list.append(hopped_dict)
        final_data = pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i5_correct','reads','dual_plate_id','dual_plate_well','reads'])
    else:
        print("ERROR: wrong sequencer")
    
    if final_data.empty:
        print("No hopped indices")
    else:
        print(''.join(['You have ', str(len(final_data)), ' hopped indices']))
        return(final_data)

# %% [markdown]
# # Function Definition (run each block but do not change!)

# %%
#PULL ALL BARCODES FROM AN UNDETERMINED FASTQ AND RETURN DATAFRAME
def pull_barcodes(file, index_length):
    undetermined_list = []
    for i, line in enumerate(open(file, 'r')):
        if i%4==0:
            line_split=line.split(":")[-1].strip('\n').split('+')
            if len(line_split[0]) == index_length:
                undetermined_dict = {'i7_barcode':line_split[0],
                                     'i5_barcode':line_split[1]}
                undetermined_list.append(undetermined_dict)
            else:
                raise Exception('Index length given does not match index length in Undetermined file')
    undetermined_df = pd.DataFrame(undetermined_list, index = None)
    return(undetermined_df)

# %%
#FIND THE TOP UNDETERMINED BARCODES FROM A DATAFRAME FROM pull_barcodes() AND RETURN DATAFRAME
def top_undetermined_barcodes(undetermined_barcodes_df, num_top_barcodes):
    tally = pd.DataFrame(undetermined_barcodes_df.groupby(['i7_barcode','i5_barcode']).size()).sort_values(by = 0, ascending = False)
    tally_subset = tally[0:num_top_barcodes].reset_index()
    tally_subset.columns = ['i7_barcode','i5_barcode','reads']
    return tally_subset

# %%
def check_barcode_length(top_undetermined, index_length):
    if ((len(top_undetermined.loc[0]['i7_barcode']) and len(top_undetermined.loc[0]['i7_barcode'])) != index_length):
        raise Exception("Index length does not match Undetermined barcode length.")

# %%
#FILTER OUT ANY UNDETERMINED THAT HAVE GGGGGGGGGGG IN THEM AND RETURN pull_barcodes()/top_undetermined_barcodes() DATAFRAME
def filter_G_homopolymer_barcodes(top_undetermined):
    filtered = top_undetermined[(top_undetermined['i7_barcode']!='GGGGGGGGGGGG') 
                                & (top_undetermined['i5_barcode']!='GGGGGGGGGGGG') 
                                & (top_undetermined['i7_barcode'] !='GGGGGGGG') & (top_undetermined['i5_barcode'] !='GGGGGGGG')].reset_index()
    print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(filtered)),' barcodes did not contain a G homopolymer.']))
    return filtered

# %%
def get_column_names(sequencer, index_length):
    if sequencer in ['iSeq','NextSeq','iseq','nextseq']:
        if index_length == 12:
            return 'i7_index_RC','i5_index_RC'
        elif index_length == 8:
            return 'i7_8bp_RC','i5_8bp_RC'
    elif sequencer in ['MiSeq','NovaSeq','miseq','novaseq']: 
        if index_length == 12:
            return 'i7_index_RC','i5_index_F'
        elif index_lengh == 8:
            return 'i7_8bp_RC','i5_8bp_F'
    raise Exception("Not a valid combination of sequencer and index length")

# %%
assert get_column_names('iseq',8) == ('i7_8bp_RC', 'i5_8bp_RC')

# %%
#IDENTIFY ANY BARCODES WHICH ARE TRUSEQ DUAL UNIQUE FROM top_undetermined_barcodes() DATAFRAME AND RETURN DATAFRAME WITH CONCLUSION
def TruSeq_dual_unique_check(top_undetermined,sequencer,index_length):  
    check_barcode_length(top_undetermined, index_length)
    i7_name, i5_name = get_column_names(sequencer, index_length)
    master_index_list = pd.read_csv("../TruSeq_8-12bp_Indices_Sample_Sheet/2018-11-02-TRUSEQ-8-12BP-INDEX-PRIMERS-PLATES-001-to-012-MasterIndexList-plus8bp_020619.csv")
    outside_sample_sheet = [];
    for i in top_undetermined.index:
        outside_matches = master_index_list.loc[(master_index_list[i7_name]==top_undetermined.loc[i]['i7_barcode'])
              & (master_index_list[i5_name]==top_undetermined.loc[i]['i5_barcode'])]
        outside_dict = {'i7_barcode' : top_undetermined.loc[i]['i7_barcode'],
                            'i5_barcode' : top_undetermined.loc[i]['i5_barcode'],
                            'reads' : top_undetermined.loc[i]['reads']}
        if outside_matches.empty:
            outside_dict.update( {'Dual_Plate_ID' : 'NA',
                            'well' : 'NA',
                            'demux_conclusion': "not a TruSeq dual-unique index pair"})
        else:
            outside_dict.update({
                            'Dual_Plate_ID' : outside_matches['Dual_Plate_ID'].values[0],
                            'well' : outside_matches['Barcode_Well'].values[0],
                            'demux_conclusion': "is a TruSeq dual-unique pair, may be outside sample sheet"})
        outside_sample_sheet.append(outside_dict)
    return pd.DataFrame(outside_sample_sheet, columns = ['i7_barcode','i5_barcode','reads','demux_conclusion','Dual_Plate_ID','well'])

# %%
def TruSeq_dual_unique_filter(top_undetermined,sequencer,index_length):  
    df = TruSeq_dual_unique_check(top_undetermined, sequencer, index_length)
    df = df[df['Dual_Plate_ID'] == 'NA']
    print(''.join(['Of ',str(len(top_undetermined)),' barcodes given, ', str(len(df)),' barcodes were not TruSeq dual-unique indices.']))
    return df[['i7_barcode','i5_barcode','reads']].reset_index()

# assert (
#     _TruSeq_dual_unique_filter(G_filtered,sequencer,index_length).values ==
#     _TruSeq_dual_unique_filter2(G_filtered,sequencer,index_length).values
# ).all()

# # Make this the "real" one
# TruSeq_dual_unique_filter = _TruSeq_dual_unique_filter2

# %%
#IDENTIFY ANY TOP UNDETERMINED BARCODES FROM top_undetermined_barcodes() DATAFRAME WHICH MAY HAVE HOPPED ON THIS RUN AND RETURN DATAFRAME
def hopped_indices(top_undetermined, dual_index_plates, sequencer, index_length):
    #check index len = undetermined length
    check_barcode_length(top_undetermined, index_length)

    #get column names
    i7_name, i5_name = get_column_names(sequencer, index_length)
    
    #read in master list of barcodes
    master_index_list = pd.read_csv("../TruSeq_8-12bp_Indices_Sample_Sheet/2018-11-02-TRUSEQ-8-12BP-INDEX-PRIMERS-PLATES-001-to-012-MasterIndexList-plus8bp_020619.csv")
    
    #subset to plates used in this run
    subset_master_index_list = master_index_list.loc[master_index_list['Dual_Plate_ID'].isin(dual_index_plates)]
    hopped_list = []
    hopped_indices = top_undetermined.loc[top_undetermined['i7_barcode'].isin(master_index_list[i7_name]) 
                                          & top_undetermined['i5_barcode'].isin (master_index_list[i5_name])]
    #identify the correct i5 based on a fixed i7 and print the correct plate and the location
    for i in hopped_indices.index:
        i7_barcode = hopped_indices.loc[i]['i7_barcode']
        i5_barcode = hopped_indices.loc[i]['i5_barcode']
        hopped_dict = {'i7_barcode':i7_barcode,
                      'i5_barcode': i5_barcode,
                      'reads':hopped_indices.loc[i]['reads']}

        filt_subset_master_index_list = subset_master_index_list[subset_master_index_list[i7_name]==i7_barcode]
        if filt_subset_master_index_list.empty: #if i7 barcode is not on your run
            hopped_dict.update({
               'i5_correct':'Not on a plate in your sample sheet',
               'dual_plate_id_i7_match': 'Not a plate in your sample sheet',
               'dual_plate_well_i7_match':'Not a plate in your sample sheet'})
        elif (filt_subset_master_index_list[i5_name].values[0]) != (hopped_indices[hopped_indices['i7_barcode']==i7_barcode]['i5_barcode'].values[0]): #else if it is on the run & the i5 is not what it is supposed to be
            hopped_dict.update({
                           'i5_correct':filt_subset_master_index_list[i5_name].values[0],
                           'dual_plate_id_i7_match':filt_subset_master_index_list['Dual_Plate_ID'].values[0],
                           'dual_plate_well_i7_match':filt_subset_master_index_list['Barcode_Well'].values[0]})

        filt_subset_master_index_list = subset_master_index_list[subset_master_index_list[i5_name]==i5_barcode]
        
        if filt_subset_master_index_list.empty: # if i5 barcode is not on your run
            hopped_dict.update({
               'i7_correct':'Not on a plate in your sample sheet',
               'dual_plate_id_i5_match': 'Not a plate in your sample sheet',
               'dual_plate_well_i5_match':'Not a plate in your sample sheet'})
        elif (filt_subset_master_index_list[i7_name].values[0]) != (hopped_indices[hopped_indices['i5_barcode']==i5_barcode]['i7_barcode'].values[0]):
            hopped_dict.update({
                           'i7_correct':filt_subset_master_index_list[i7_name].values[0],
                           'dual_plate_id_i5_match':filt_subset_master_index_list['Dual_Plate_ID'].values[0],
                           'dual_plate_well_i5_match':filt_subset_master_index_list['Barcode_Well'].values[0]})
        hopped_list.append(hopped_dict)
    final_data = pd.DataFrame(hopped_list,columns = ['i7_barcode','i5_barcode','i7_correct','i5_correct','reads','dual_plate_id_i7_match','dual_plate_well_i7_match','dual_plate_id_i5_match','dual_plate_well_i5_match'])
    
    
    if final_data.empty:
        print("No hopped indices within the plates on your sample sheet")
        return(final_data)
    else:
        print(''.join(['You have ', str(len(final_data)), ' hopped barcodes within the plate on your sample sheet']))
        return(final_data)

# %%
def filter_hopped_indices(filtered, hopped_index):
    leftover_indices = filtered
    if hopped_index.empty:
        leftover_indices = filtered
    else:
        for i in filtered.index: 
            if filtered.loc[i]['i7_barcode'] in list(hopped_index['i7_barcode']):
                if filtered.loc[i]['i5_barcode'] == hopped_index[hopped_index['i7_barcode']==filtered.loc[i]['i7_barcode']]['i5_barcode'].values[0]:
                    leftover_indices = leftover_indices.drop(i)[['i7_barcode','i5_barcode','reads']]
    print(''.join(['You have ',str(len(leftover_indices)),' barcodes remaining']))
    return leftover_indices.reset_index()

# %%
def match_i5_or_i7(leftover_indices,sequencer,index_length,dual_index_plates):
    
    #check index len = undetermined length
    check_barcode_length(top_undetermined, index_length)

    #get column names
    i7_name, i5_name = get_column_names(sequencer, index_length)

    #read in master list of barcodes
    master_index_list = pd.read_csv("../TruSeq_8-12bp_Indices_Sample_Sheet/2018-11-02-TRUSEQ-8-12BP-INDEX-PRIMERS-PLATES-001-to-012-MasterIndexList-plus8bp_020619.csv")
    #subset to plates used in this run
    subset_master_index_list = master_index_list.loc[master_index_list['Dual_Plate_ID'].isin(dual_index_plates)]
    leftover_list = [];
    
    print(leftover_indices)
    
    #match identical i7
    for i7_barcode in leftover_indices['i7_barcode']:
        filt_subset_master_index_list = subset_master_index_list[subset_master_index_list[i7_name]==i7_barcode]
        if filt_subset_master_index_list.empty: 
            if i7_barcode in list(master_index_list[i7_name]):
                    leftover_dict = {'i7_barcode':i7_barcode,
                         'i5_barcode': leftover_indices[leftover_indices['i7_barcode']==i7_barcode]['i5_barcode'].values[0],
                         'reads': leftover_indices[leftover_indices['i7_barcode']==i7_barcode]['reads'].values[0],
                         'i7_correct':i7_barcode,
                         'i5_correct':"i5 does not match an index in our TruSeq dataset",
                         'dual_plate_id':"Not a plate in your sample sheet",
                         'dual_plate_well':"N/A",
                         'description': 'i7 matches 100% with an i7 in TruSeq dataset, i5 does not'}
            else:
                continue
        else:
            leftover_dict = {'i7_barcode':i7_barcode,
                             'i5_barcode': leftover_indices[leftover_indices['i7_barcode']==i7_barcode]['i5_barcode'].values[0],
                             'reads': leftover_indices[leftover_indices['i7_barcode']==i7_barcode]['reads'].values[0],
                             'i7_correct':i7_barcode,
                             'i5_correct':filt_subset_master_index_list[i5_name].values[0],
                             'dual_plate_id':filt_subset_master_index_list['Dual_Plate_ID'].values[0],
                             'dual_plate_well':filt_subset_master_index_list['Barcode_Well'].values[0],
                             'description': 'i7 matches 100% with an i7 in sample sheet, i5 does not'}
            leftover_dict['mismatches'] = sum(c1!=c2 for c1,c2 in zip(leftover_dict['i5_barcode'], leftover_dict['i5_correct']))
        leftover_list.append(leftover_dict)
    matchingi7 = len(leftover_list)
    print(''.join(['Of ',str(len(leftover_indices)),' barcodes given, ', str(matchingi7),' barcodes had an i7 perfectly matching an i7 in the plate on your sample sheet.']))

    #match identical i5
    for i5_barcode in leftover_indices['i5_barcode']:
        filt_subset_master_index_list = subset_master_index_list[subset_master_index_list[i5_name]==i5_barcode]
        if filt_subset_master_index_list.empty: 
            if i5_barcode in list(master_index_list[i5_name]):
                    leftover_dict = {'i7_barcode':leftover_indices[leftover_indices['i5_barcode']==i5_barcode]['i7_barcode'].values[0],
                         'i5_barcode': i5_barcode,
                         'reads': leftover_indices[leftover_indices['i5_barcode']==i5_barcode]['reads'].values[0],
                         'i7_correct':"i7 does not match an index in our TruSeq dataset",
                         'i5_correct': i5_barcode,
                         'dual_plate_id':"Not a plate in your sample sheet",
                         'dual_plate_well':"N/A",
                         'description': 'i5 matches 100% with an i5 in TruSeq dataset, i7 does not'}
            else:
                continue
        leftover_dict = {'i7_barcode': leftover_indices[leftover_indices['i5_barcode']==i5_barcode]['i7_barcode'].values[0],
                         'i5_barcode':i5_barcode,
                         'reads': leftover_indices[leftover_indices['i5_barcode']==i5_barcode]['reads'].values[0],
                         'i7_correct':filt_subset_master_index_list[i7_name].values[0],
                         'i5_correct':i5_barcode,
                         'dual_plate_id':filt_subset_master_index_list['Dual_Plate_ID'].values[0],
                         'dual_plate_well':filt_subset_master_index_list['Barcode_Well'].values[0],
                         'description': 'i5 matches 100% with an i5 in sample sheet, i7 does not'}
        leftover_dict['mismatches'] = sum(c1!=c2 for c1,c2 in zip(leftover_dict['i7_barcode'], leftover_dict['i7_correct']))
        leftover_list.append(leftover_dict)
    print(''.join(['Of ',str(len(leftover_indices)),' barcodes given, ', str(len(leftover_list)-matchingi7),' barcodes had an i5 perfectly matching an i5 in the plate on your sample sheet.']))
    final_data = pd.DataFrame(leftover_list,columns = ['i7_barcode','i5_barcode','i7_correct','i5_correct','reads','dual_plate_id','dual_plate_well','reads','mismatches','description'])
    
    return final_data

# %% [markdown]
# # Set your index length, sequencer, number of undetermined barcodes you wish to investigate, your index plates, and your Undetermined file

# %%
index_length = 12;
sequencer = 'novaseq';
number_undetermined_barcodes = 10000;
index_plates = ["Dual-122","Dual-123","Dual-124","Dual-125"]
#index_plates = ["Dual-096","Dual-097","Dual-098","Dual-099"]
file = "seq5mil_Undetermined_S0_L001_R1_001.fastq"

# %% [markdown]
# # Run to pull out all the barcodes from the Undetermined fastq

# %%
undetermined_barcodes_df = pull_barcodes(file, index_length)
# Out:
# 5000000

# %% [markdown]
# # View your top undetermined barcodes

# %%
top_undetermined = top_undetermined_barcodes(undetermined_barcodes_df,number_undetermined_barcodes)
top_undetermined.to_csv("Top_Undetermined_Barcodes.csv")
top_undetermined.head(10)
# Out:
#      i7_barcode    i5_barcode    reads
# 0  GGGGGGGGGGGG  TCTTTCCCTACA  2352142
# 1  ACGAGACACCTT  AGCAACTGGAAC    73163
# 2  AGTGACCCGGAG  GACACAGAACTC    63573
# 3  AGTGCGTGTTCA  ACAGGATGTCGT    36858
# 4  GGGGGGGGGGGG  NCTTTCCCTACA    17379
# 5  GGGGGGGGGGGG  TCTTTCCNTACA    15842
# 6  GGGGGGGGGGGG  TCTTTACCTACA    15450
# 7  GGGGGGGGGGGG  AACAGTGCCTTG    12429
# 8  GGGGGGGGGGGG  TCTTTCCCTACN    10787
# 9  GGGGGGGGGGGG  TTAGCGTGACTC    10264

# %% [markdown]
# # Filter out any which are all "G" (adaptor reads)

# %%
G_filtered = filter_G_homopolymer_barcodes(top_undetermined)
G_filtered.head(10)
# Out:
# Of 10000 barcodes given, 9514 barcodes did not contain a G homopolymer.
#    index    i7_barcode    i5_barcode  reads
# 0      1  ACGAGACACCTT  AGCAACTGGAAC  73163
# 1      2  AGTGACCCGGAG  GACACAGAACTC  63573
# 2      3  AGTGCGTGTTCA  ACAGGATGTCGT  36858
# 3     12  AAGAGGTATCGA  TTAGCGTGACTC   8648
# 4     14  CAGAGGTATCGA  TTAGCGTGACTC   8067
# 5     15  CAAGAGTATCGA  TTAGCGTGACTC   8032
# 6     17  CAANAGGGATCG  TTAGCGTNACTC   7338
# 7     20  GGGNGGGGGGGG  TCTTTCCNTACA   6929
# 8     21  ACGAGTTATCGA  CGGTACTAACTC   6549
# 9     22  AGTGACGCGTTA  CTGCACAACTCA   6374

# %% [markdown]
# # View which barcodes were not TruSeq dual-unique index pairs and which were, but did not demux properly
# This may suggest samples had barcodes which were not listed on your sample sheet

# %%
TruSeqcheck=TruSeq_dual_unique_check(G_filtered,sequencer,index_length)
TruSeqcheck.to_csv("TruSeq_Dual_Unique_Check.csv")
TruSeqcheck
# Out:
#         i7_barcode    i5_barcode  reads  \
# 0     ACGAGACACCTT  AGCAACTGGAAC  73163
# 1     AGTGACCCGGAG  GACACAGAACTC  63573
# 2     AGTGCGTGTTCA  ACAGGATGTCGT  36858
# 3     AAGAGGTATCGA  TTAGCGTGACTC   8648
# 4     CAGAGGTATCGA  TTAGCGTGACTC   8067
# 5     CAAGAGTATCGA  TTAGCGTGACTC   8032
# 6     CAANAGGGATCG  TTAGCGTNACTC   7338
# 7     GGGNGGGGGGGG  TCTTTCCNTACA   6929
# 8     ACGAGTTATCGA  CGGTACTAACTC   6549
# 9     AGTGACGCGTTA  CTGCACAACTCA   6374
# 10    GGGNGGGGGGGG  TCTTTCCCTACA   5983
# 11    AGTGACGCGTTA  CTGCAACACTCA   5202
# 12    TGCNTCCGCCAA  AGGAGAANCACT   5040
# 13    CAAAGGTATCGA  TTAGCGTGACTC   4886
# 14    AGTGCTCGGTTA  AACAGTGCCTTG   4571
# 15    CAAGCGTTAGCA  ACACACTTCGTA   4434
# 16    CAAGAGGTATCG  TAGCGTGACTCA   4429
# 17    TCACGCTACTGA  CGAAGATCGTGA   4349
# 18    AGTCTACGGTTA  AACAGTGCCTTG   4207
# 19    AGTNACGGGTTA  CTGCAACNACTC   4161
# 20    AGTGACGCGTTA  TGCAACAACTCA   4018
# 21    TGCTTCCTCCAA  GGAGAAGCACTA   3973
# 22    CAAGGATCTGGT  CCATATGCGTGA   3757
# 23    CAANAGGGATCG  TTAGCGTGACTC   3651
# 24    AGTGACGCGTTA  CTGAACAACTCA   3598
# 25    GGNGGGGGGGGG  NCTTTCCCTACA   3538
# 26    TGCTTCCTCCAA  AGGAGAGCACTA   3518
# 27    TGCNATCGCCTC  GTTGGTTNTCGT   3513
# 28    AGTGTGACACAG  TCTCGGATCTTG   3420
# 29    GTTCTCCACTTC  AAGCTCACTGAG   3313
# ...            ...           ...    ...
# 9484  ATAAAACATTAC  AAAACAAAAATC     18
# 9485  ACGAGTTGTCGA  TATTAACCAACA     18
# 9486  TCACCAGAAGCA  AGCAACTGGAAC     18
# 9487  CAAGAGGTATCG  TAACCGTGACTC     18
# 9488  GAGTGTGACAGT  GCTACACAAACA     18
# 9489  AGTGCTACGGTT  AAAAGTGCCTTN     18
# 9490  TGCTTCCTCCAA  AGTACAAGAAAA     18
# 9491  GAGTCACACATG  TGCGCACGCGTG     18
# 9492  GGGGCGGGAGGT  CGATGTGAGAAC     18
# 9493  ACAACAACAAAA  CAAATTCATAAC     18
# 9494  GTTCCGTAAAAG  TTGCCAGTACTC     18
# 9495  TCACAGCACTAC  GATCACTGAGAG     18
# 9496  AAACCTGCATAT  CTATTAAAAAAC     18
# 9497  ATTCAAGCCTTA  CTCAAAAAACAA     18
# 9498  CAAGTCGCTCAA  TGTAATGACACT     18
# 9499  CAAGAGGTATCG  TTAGCATTACTC     18
# 9500  GTTCTCACATCG  GCGATTAGTGAA     18
# 9501  CTCAAAAGATCC  ACAAGGACCTTG     18
# 9502  TCCATCAAACAA  AGAAGAACCACA     18
# 9503  TCACCAGAAGCA  GGGGCTGCCACT     18
# 9504  AGTGCTAAGGGT  AACAGTGCCTTG     18
# 9505  CAACAGTAATCG  TTGCCCGTACTC     18
# 9506  CAAGCGTAGCAT  CACACACTTCGT     18
# 9507  AAACAGAAATAC  GAAATCACACAC     18
# 9508  GTTCATTGCTGC  GGCGAGATCGCA     18
# 9509  CAAGAGGTATCG  TTAGCGAAACTC     18
# 9510  CAAGCGTAAGAA  CACACACTTCGT     18
# 9511  CAAGAGGTATCG  TTATGACTCACA     18
# 9512  GTTCCCAAATCG  TTGCCAGTACTC     18
# 9513  CAAGAGGTATCG  NTGCGTGACTCA     18
#
#                                        demux_conclusion Dual_Plate_ID well
# 0     is a TruSeq dual-unique pair, may be outside s...      Dual-122  F12
# 1                   not a TruSeq dual-unique index pair            NA   NA
# 2     is a TruSeq dual-unique pair, may be outside s...      Dual-124   A7
# 3                   not a TruSeq dual-unique index pair            NA   NA
# 4                   not a TruSeq dual-unique index pair            NA   NA
# 5                   not a TruSeq dual-unique index pair            NA   NA
# 6                   not a TruSeq dual-unique index pair            NA   NA
# 7                   not a TruSeq dual-unique index pair            NA   NA
# 8                   not a TruSeq dual-unique index pair            NA   NA
# 9                   not a TruSeq dual-unique index pair            NA   NA
# 10                  not a TruSeq dual-unique index pair            NA   NA
# 11                  not a TruSeq dual-unique index pair            NA   NA
# 12                  not a TruSeq dual-unique index pair            NA   NA
# 13                  not a TruSeq dual-unique index pair            NA   NA
# 14                  not a TruSeq dual-unique index pair            NA   NA
# 15                  not a TruSeq dual-unique index pair            NA   NA
# 16                  not a TruSeq dual-unique index pair            NA   NA
# 17                  not a TruSeq dual-unique index pair            NA   NA
# 18                  not a TruSeq dual-unique index pair            NA   NA
# 19                  not a TruSeq dual-unique index pair            NA   NA
# 20                  not a TruSeq dual-unique index pair            NA   NA
# 21                  not a TruSeq dual-unique index pair            NA   NA
# 22    is a TruSeq dual-unique pair, may be outside s...      Dual-122  B10
# 23                  not a TruSeq dual-unique index pair            NA   NA
# 24                  not a TruSeq dual-unique index pair            NA   NA
# 25                  not a TruSeq dual-unique index pair            NA   NA
# 26                  not a TruSeq dual-unique index pair            NA   NA
# 27                  not a TruSeq dual-unique index pair            NA   NA
# 28    is a TruSeq dual-unique pair, may be outside s...      Dual-124   E1
# 29    is a TruSeq dual-unique pair, may be outside s...      Dual-124   D5
# ...                                                 ...           ...  ...
# 9484                not a TruSeq dual-unique index pair            NA   NA
# 9485                not a TruSeq dual-unique index pair            NA   NA
# 9486                not a TruSeq dual-unique index pair            NA   NA
# 9487                not a TruSeq dual-unique index pair            NA   NA
# 9488                not a TruSeq dual-unique index pair            NA   NA
# 9489                not a TruSeq dual-unique index pair            NA   NA
# 9490                not a TruSeq dual-unique index pair            NA   NA
# 9491                not a TruSeq dual-unique index pair            NA   NA
# 9492                not a TruSeq dual-unique index pair            NA   NA
# 9493                not a TruSeq dual-unique index pair            NA   NA
# 9494                not a TruSeq dual-unique index pair            NA   NA
# 9495                not a TruSeq dual-unique index pair            NA   NA
# 9496                not a TruSeq dual-unique index pair            NA   NA
# 9497                not a TruSeq dual-unique index pair            NA   NA
# 9498                not a TruSeq dual-unique index pair            NA   NA
# 9499                not a TruSeq dual-unique index pair            NA   NA
# 9500                not a TruSeq dual-unique index pair            NA   NA
# 9501                not a TruSeq dual-unique index pair            NA   NA
# 9502                not a TruSeq dual-unique index pair            NA   NA
# 9503                not a TruSeq dual-unique index pair            NA   NA
# 9504                not a TruSeq dual-unique index pair            NA   NA
# 9505                not a TruSeq dual-unique index pair            NA   NA
# 9506                not a TruSeq dual-unique index pair            NA   NA
# 9507                not a TruSeq dual-unique index pair            NA   NA
# 9508                not a TruSeq dual-unique index pair            NA   NA
# 9509                not a TruSeq dual-unique index pair            NA   NA
# 9510                not a TruSeq dual-unique index pair            NA   NA
# 9511                not a TruSeq dual-unique index pair            NA   NA
# 9512                not a TruSeq dual-unique index pair            NA   NA
# 9513                not a TruSeq dual-unique index pair            NA   NA
#
# [9514 rows x 6 columns]

# %%
dualuniq_G_filtered = TruSeq_dual_unique_filter(G_filtered,sequencer,index_length)
dualuniq_G_filtered
# Out:
# Of 9514 barcodes given, 9469 barcodes were not TruSeq dual-unique indices.
#       index    i7_barcode    i5_barcode  reads
# 0         1  AGTGACCCGGAG  GACACAGAACTC  63573
# 1         3  AAGAGGTATCGA  TTAGCGTGACTC   8648
#
# 9468   9513  CAAGAGGTATCG  NTGCGTGACTCA     18
#
# [9469 rows x 4 columns]

# %% [markdown]
# # View which barcodes had potential index hopping
# This suggest index hopping - does not include index hopping across plates not used on your library preparation run

# %%
hopped_index = hopped_indices(dualuniq_G_filtered,index_plates,sequencer, index_length)
hopped_index.to_csv("Hopped_Indices.csv")
hopped_index
# Out:
# You have 1235 hopped barcodes within the plate on your sample sheet
#         i7_barcode    i5_barcode    i7_correct    i5_correct  reads  \
# 0     CAAGAGGTACGA  TTAGCGTGACTC  CAAGAGGTATCG  ACCTAGAGAGCA   2562
# 1     CTCACAAGTTCC  TTAGCGTGACTC  CAAGAGGTATCG  ACAAGGACCTTG   1440
# 2     ACGAGTTGTCGA  CGGTACTAACTC  ACGAGTTATCCG  GTTGAAGCCTTG   1392
# 3     TCACGCTAACTG  TTAGCGTGACTC  CAAGAGGTATCG  CGAAGATCGTGA   1313
# 4     CTCAGTGAGCTT  TTAGCGTGACTC  CAAGAGGTATCG  AGTGCGATACTC   1297
# 5     TCACCTGGAGTT  TTAGCGTGACTC  CAAGAGGTATCG  CGATGTGAGAAC   1226
# 6     ACGAGTTGTCGA  TTAGCGTGACTC  CAAGAGGTATCG  GTTGAAGCCTTG   1220
# 7     CAAGAGGTATCG  AGTGCGATACTC  CTCAGTGAGCTT  TTAGCGTGACTC   1205
# 8     CAAGAGGTATCG  AACAGTGCCTTG  AGTGCTACGGTT  TTAGCGTGACTC   1193
# 9     CTCACAAGTTCC  AACAGTGCCTTG  AGTGCTACGGTT  ACAAGGACCTTG   1174
# 10    ACGAGTTGTCGA  AACAGTGCCTTG  AGTGCTACGGTT  GTTGAAGCCTTG   1165
# 11    ACGAATCCTGTC  CGGTACTAACTC  ACGAGTTATCCG  AGCTCTGAAGCA   1089
# 12    CTCACAAGTTCC  CGGTACTAACTC  ACGAGTTATCCG  ACAAGGACCTTG   1072
# 13    CAAGAGGTATCG  CTGCAACAACTC  AGTGACGCGTTA  TTAGCGTGACTC   1029
# 14    TCACGCTAACTG  AACAGTGCCTTG  AGTGCTACGGTT  CGAAGATCGTGA   1023
# 15    AGTGCTACGGTT  TTAGCGTGACTC  CAAGAGGTATCG  AACAGTGCCTTG    999
# 16    TCACCTGGAGTT  CGGTACTAACTC  ACGAGTTATCCG  CGATGTGAGAAC    992
# 17    TCACCTGGAGTT  AACAGTGCCTTG  AGTGCTACGGTT  CGATGTGAGAAC    972
# 18    CTCACAAGTTCC  AGTGCGATACTC  CTCAGTGAGCTT  ACAAGGACCTTG    972
# 19    TCACCAGAAGCA  TTAGCGTGACTC  CAAGAGGTATCG  GGTTCTTCCACT    964
# 20    TCACGCTAACTG  CGGTACTAACTC  ACGAGTTATCCG  CGAAGATCGTGA    956
# 21    ACGAATCCTGTC  TTAGCGTGACTC  CAAGAGGTATCG  AGCTCTGAAGCA    952
# 22    TGCTTCCTCCAA  TTAGCGTGACTC  CAAGAGGTATCG  AGGAGAAGCACT    943
# 1222               Dual-124                      D11               Dual-125
# 1223               Dual-123                       B1               Dual-125
# 1224               Dual-124                      G11               Dual-125
# 1225               Dual-124                       G2               Dual-122
# 1226               Dual-123                      F12               Dual-123
# 1227               Dual-122                       D4               Dual-124
# 1228               Dual-124                       C3               Dual-124
# 1229               Dual-125                       C2               Dual-125
# 1230               Dual-123                       A1               Dual-124
# 1231               Dual-123                       D2               Dual-125
# 1232               Dual-124                      D12               Dual-122
# 1233               Dual-125                       G4               Dual-122
# 1234               Dual-125                      B10               Dual-122
#
#      dual_plate_well_i5_match
# 0                          C6
# 1                          C6
# 2                          C6
# 3                          C6
# 4                          C6
# 5                          C6
# 6                          C6
# 7                          D4
# 8                          H2
# 9                          H2
# 10                         H2
# 11                         C6
# 12                         C6
# 13                        F10
# 14                         H2
# 15                         C6
# 16                         C6
# 17                         H2
# 18                         D4
# 19                         C6
# 20                         C6
# 21                         C6
# 22                         C6
# 23                         C3
# 24                         C6
# 25                         C6
# 26                         F2
# 27                         C6
# 28                         F2
# 29                         H7
# ...                       ...
# 1205                       C2
# 1206                       C2
# 1207                       H1
# 1208                       C2
# 1209                       A5
# 1210                       B1
# 1211                      A10
# 1212                       H2
# 1213                       B1
# 1214                       A9
# 1215                       C7
# 1216                       D1
# 1217                       C6
# 1218                      H10
# 1219                      G11
# 1220                       G4
# 1221                       F2
# 1222                       G4
# 1223                       G4
# 1224                       A5
# 1225                       A2
# 1226                       A1
# 1227                       A7
# 1228                      H12
# 1229                       A5
# 1230                       C7
# 1231                       A9
# 1232                       A2
# 1233                       A2
# 1234                      F12
#
# [1235 rows x 9 columns]

# %% [markdown]
# # Filter which barcodes which were not index hopping cases, or G homopolymers
# These may be samples which either had IDT synthesis errors or were frequently misread by the sequencer

# %%
leftover = filter_hopped_indices(dualuniq_G_filtered, hopped_index)
leftover
# Out:
# You have 9424 barcodes remaining
#       index    i7_barcode    i5_barcode  reads
# 0         0  AGTGACCCGGAG  GACACAGAACTC  63573
# 1         1  AAGAGGTATCGA  TTAGCGTGACTC   8648
# 2         2  CAGAGGTATCGA  TTAGCGTGACTC   8067
# 3         3  CAAGAGTATCGA  TTAGCGTGACTC   8032
# 4         4  CAANAGGGATCG  TTAGCGTNACTC   7338
# 5         5  GGGNGGGGGGGG  TCTTTCCNTACA   6929
# 6         6  ACGAGTTATCGA  CGGTACTAACTC   6549
# 7         7  AGTGACGCGTTA  CTGCACAACTCA   6374
# 8         8  GGGNGGGGGGGG  TCTTTCCCTACA   5983
# 9         9  AGTGACGCGTTA  CTGCAACACTCA   5202
# 10       10  TGCNTCCGCCAA  AGGAGAANCACT   5040
# 11       11  CAAAGGTATCGA  TTAGCGTGACTC   4886
# 12       12  AGTGCTCGGTTA  AACAGTGCCTTG   4571
# 13       13  CAAGCGTTAGCA  ACACACTTCGTA   4434
# 14       14  CAAGAGGTATCG  TAGCGTGACTCA   4429
# 15       15  TCACGCTACTGA  CGAAGATCGTGA   4349
# 16       16  AGTCTACGGTTA  AACAGTGCCTTG   4207
# 17       17  AGTNACGGGTTA  CTGCAACNACTC   4161
# 18       18  AGTGACGCGTTA  TGCAACAACTCA   4018
# 19       19  TGCTTCCTCCAA  GGAGAAGCACTA   3973
# 20       20  CAANAGGGATCG  TTAGCGTGACTC   3651
# 21       21  AGTGACGCGTTA  CTGAACAACTCA   3598
# 22       22  GGNGGGGGGGGG  NCTTTCCCTACA   3538
# 23       23  TGCTTCCTCCAA  AGGAGAGCACTA   3518
# 24       24  TGCNATCGCCTC  GTTGGTTNTCGT   3513
# 25       25  GTTCATGCTGCA  GGCTAGATAGCA   3312
# 26       26  AGTGACGCGTTA  CTGCAAAACTCA   3276
# 27       27  CAAGAGGTATGA  TTAGCGTGACTC   3176
# 28       28  GTGCTACGGTTA  AACAGTGCCTTG   3162
# 29       29  GTCATTGCTGCA  GGCTAGATAGCA   3110
# ...     ...           ...           ...    ...
# 9394   9439  ATAAAACATTAC  AAAACAAAAATC     18
# 9395   9440  ACGAGTTGTCGA  TATTAACCAACA     18
# 9396   9441  TCACCAGAAGCA  AGCAACTGGAAC     18
# 9397   9442  CAAGAGGTATCG  TAACCGTGACTC     18
# 9398   9443  GAGTGTGACAGT  GCTACACAAACA     18
# 9399   9444  AGTGCTACGGTT  AAAAGTGCCTTN     18
# 9400   9445  TGCTTCCTCCAA  AGTACAAGAAAA     18
# 9401   9446  GAGTCACACATG  TGCGCACGCGTG     18
# 9402   9447  GGGGCGGGAGGT  CGATGTGAGAAC     18
# 9403   9448  ACAACAACAAAA  CAAATTCATAAC     18
# 9404   9449  GTTCCGTAAAAG  TTGCCAGTACTC     18
# 9405   9450  TCACAGCACTAC  GATCACTGAGAG     18
# 9406   9451  AAACCTGCATAT  CTATTAAAAAAC     18
# 9407   9452  ATTCAAGCCTTA  CTCAAAAAACAA     18
# 9408   9453  CAAGTCGCTCAA  TGTAATGACACT     18
# 9409   9454  CAAGAGGTATCG  TTAGCATTACTC     18
# 9410   9455  GTTCTCACATCG  GCGATTAGTGAA     18
# 9411   9456  CTCAAAAGATCC  ACAAGGACCTTG     18
# 9412   9457  TCCATCAAACAA  AGAAGAACCACA     18
# 9413   9458  TCACCAGAAGCA  GGGGCTGCCACT     18
# 9414   9459  AGTGCTAAGGGT  AACAGTGCCTTG     18
# 9415   9460  CAACAGTAATCG  TTGCCCGTACTC     18
# 9416   9461  CAAGCGTAGCAT  CACACACTTCGT     18
# 9417   9462  AAACAGAAATAC  GAAATCACACAC     18
# 9418   9463  GTTCATTGCTGC  GGCGAGATCGCA     18
# 9419   9464  CAAGAGGTATCG  TTAGCGAAACTC     18
# 9420   9465  CAAGCGTAAGAA  CACACACTTCGT     18
# 9421   9466  CAAGAGGTATCG  TTATGACTCACA     18
# 9422   9467  GTTCCCAAATCG  TTGCCAGTACTC     18
# 9423   9468  CAAGAGGTATCG  NTGCGTGACTCA     18
#
# [9424 rows x 4 columns]

# %% [markdown]
# # View which barcodes had a perfect match with an i7 or i5, but not with both
# These may be samples which either had IDT synthesis errors or were frequently misread by the sequencer

# %%
leftover_matched = match_i5_or_i7(leftover, sequencer, index_length,index_plates)
leftover_matched.to_csv("Leftover_Indices_Matched_to_i7_i5_SampleSheet.csv")
leftover_matched
# Out:
#       index    i7_barcode    i5_barcode  reads
# 0         0  AGTGACCCGGAG  GACACAGAACTC  63573
# 1         1  AAGAGGTATCGA  TTAGCGTGACTC   8648
# 2         2  CAGAGGTATCGA  TTAGCGTGACTC   8067
# 3         3  CAAGAGTATCGA  TTAGCGTGACTC   8032
# 4         4  CAANAGGGATCG  TTAGCGTNACTC   7338
# 5         5  GGGNGGGGGGGG  TCTTTCCNTACA   6929
# 6         6  ACGAGTTATCGA  CGGTACTAACTC   6549
# 7         7  AGTGACGCGTTA  CTGCACAACTCA   6374
# 8         8  GGGNGGGGGGGG  TCTTTCCCTACA   5983
# 9         9  AGTGACGCGTTA  CTGCAACACTCA   5202
# 10       10  TGCNTCCGCCAA  AGGAGAANCACT   5040
# 11       11  CAAAGGTATCGA  TTAGCGTGACTC   4886
# 12       12  AGTGCTCGGTTA  AACAGTGCCTTG   4571
# 13       13  CAAGCGTTAGCA  ACACACTTCGTA   4434
# 14       14  CAAGAGGTATCG  TAGCGTGACTCA   4429
# 15       15  TCACGCTACTGA  CGAAGATCGTGA   4349
# 16       16  AGTCTACGGTTA  AACAGTGCCTTG   4207
# 17       17  AGTNACGGGTTA  CTGCAACNACTC   4161
# 18       18  AGTGACGCGTTA  TGCAACAACTCA   4018
# 19       19  TGCTTCCTCCAA  GGAGAAGCACTA   3973
# 20       20  CAANAGGGATCG  TTAGCGTGACTC   3651
# 21       21  AGTGACGCGTTA  CTGAACAACTCA   3598
# 22       22  GGNGGGGGGGGG  NCTTTCCCTACA   3538
# 23       23  TGCTTCCTCCAA  AGGAGAGCACTA   3518
# 24       24  TGCNATCGCCTC  GTTGGTTNTCGT   3513
# 25       25  GTTCATGCTGCA  GGCTAGATAGCA   3312
# 26       26  AGTGACGCGTTA  CTGCAAAACTCA   3276
# 27       27  CAAGAGGTATGA  TTAGCGTGACTC   3176
# 28       28  GTGCTACGGTTA  AACAGTGCCTTG   3162
# 29       29  GTCATTGCTGCA  GGCTAGATAGCA   3110
# ...     ...           ...           ...    ...
# 9394   9439  ATAAAACATTAC  AAAACAAAAATC     18
# 9395   9440  ACGAGTTGTCGA  TATTAACCAACA     18
# 9396   9441  TCACCAGAAGCA  AGCAACTGGAAC     18
# 9397   9442  CAAGAGGTATCG  TAACCGTGACTC     18
# 9398   9443  GAGTGTGACAGT  GCTACACAAACA     18
# 9399   9444  AGTGCTACGGTT  AAAAGTGCCTTN     18
# 9400   9445  TGCTTCCTCCAA  AGTACAAGAAAA     18
# 9401   9446  GAGTCACACATG  TGCGCACGCGTG     18
# 9402   9447  GGGGCGGGAGGT  CGATGTGAGAAC     18
# 9403   9448  ACAACAACAAAA  CAAATTCATAAC     18
# 9404   9449  GTTCCGTAAAAG  TTGCCAGTACTC     18
# 9405   9450  TCACAGCACTAC  GATCACTGAGAG     18
# 9406   9451  AAACCTGCATAT  CTATTAAAAAAC     18
# 9407   9452  ATTCAAGCCTTA  CTCAAAAAACAA     18
# 9408   9453  CAAGTCGCTCAA  TGTAATGACACT     18
# 9409   9454  CAAGAGGTATCG  TTAGCATTACTC     18
# 9410   9455  GTTCTCACATCG  GCGATTAGTGAA     18
# 9411   9456  CTCAAAAGATCC  ACAAGGACCTTG     18
# 9412   9457  TCCATCAAACAA  AGAAGAACCACA     18
# 9413   9458  TCACCAGAAGCA  GGGGCTGCCACT     18
# 9414   9459  AGTGCTAAGGGT  AACAGTGCCTTG     18
# 9415   9460  CAACAGTAATCG  TTGCCCGTACTC     18
# 9416   9461  CAAGCGTAGCAT  CACACACTTCGT     18
# 9417   9462  AAACAGAAATAC  GAAATCACACAC     18
# 9418   9463  GTTCATTGCTGC  GGCGAGATCGCA     18
# 9419   9464  CAAGAGGTATCG  TTAGCGAAACTC     18
# 9420   9465  CAAGCGTAAGAA  CACACACTTCGT     18
# 9421   9466  CAAGAGGTATCG  TTATGACTCACA     18
# 9422   9467  GTTCCCAAATCG  TTGCCAGTACTC     18
# 9423   9468  CAAGAGGTATCG  NTGCGTGACTCA     18
#
# [9424 rows x 4 columns]
# Of 9424 barcodes given, 4790 barcodes had an i7 perfectly matching an i7 in the plate on your sample sheet.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1143-75efc587819a> in <module>
# ----> 1 leftover_matched = match_i5_or_i7(leftover, sequencer, index_length,index_plates)
#       2 leftover_matched.to_csv("Leftover_Indices_Matched_to_i7_i5_SampleSheet.csv")
#       3 leftover_matched
#
# <ipython-input-1106-72ad8a132ad4> in match_i5_or_i7(leftover_indices, sequencer, index_length, dual_index_plates)
#      62                          'i5_barcode':i5_barcode,
#      63                          'reads': leftover_indices[leftover_indices['i5_barcode']==i5_barcode]['reads'].values[0],
# ---> 64                          'i7_correct':filt_subset_master_index_list[i7_name].values[0],
#      65                          'i5_correct':i5_barcode,
#      66                          'dual_plate_id':filt_subset_master_index_list['Dual_Plate_ID'].values[0],
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
